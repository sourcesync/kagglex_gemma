# %% [markdown]
# # ZZZ Web Scraping
# ## Prydwen
# ### Bangboos

# %%
# pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.prydwen.gg/zenless/w-engines/"

# %%
# engines_request = requests.get(url)

# %%
print(engines_request.content[:100])
# Out:
# b'<!DOCTYPE html><html><head><meta charSet="utf-8"/><meta http-equiv="x-ua-compatible" content="ie=edg'

# %%
soup = BeautifulSoup(engines_request.content, 'html.parser')

# %%
results = soup.find(id="___gatsby")

# %%
# print(results.prettify())

# %%
engine_elements = results.find_all("div", class_="zzz-engine")

# %%
for engine in engine_elements:
    print(engine, end="\n"*2)
# Out:
# <div class="zzz-engine"><div class="zzz-engine-header"><div class="zzz-icon rarity-S"><div class="gatsby-image-wrapper gatsby-image-wrapper-constrained disable-transition" data-gatsby-image-wrapper=""><div style="max-width:256px;display:block"><img alt="" aria-hidden="true" role="presentation" src="data:image/svg+xml;charset=utf-8,%3Csvg height='256' width='256' xmlns='http://www.w3.org/2000/svg' version='1.1'%3E%3C/svg%3E" style="max-width:100%;display:block;position:static"/></div><div aria-hidden="true" data-placeholder-image="" style="opacity:1;transition:opacity 500ms linear;background-color:#080808;position:absolute;top:0;left:0;bottom:0;right:0"></div><picture><source data-srcset="/static/1caa98f79cd184e88b1621ec66c0f794/8257c/Deep_Sea_Visitor.webp 64w,/static/1caa98f79cd184e88b1621ec66c0f794/6766a/Deep_Sea_Visitor.webp 128w,/static/1caa98f79cd184e88b1621ec66c0f794/22bfc/Deep_Sea_Visitor.webp 256w" sizes="(min-width: 256px) 256px, 100vw" type="image/webp"/><img alt="Deep Sea V
# ...

# %%
for engine in engine_elements:
    name = engine.find("h5")
    rarity = engine.find("strong", class_="rarity-S") or engine.find("strong", class_="rarity-A") or engine.find("strong", class_="rarity-B")
    # misspellings for anomoly and defense on website
    specialty = engine.find("strong", class_="type Attack") or engine.find("strong", class_="type Anomaly") or engine.find("strong", class_="type Stun") or engine.find("strong", class_="type Defence") or engine.find("strong", class_="type Support")
    description = engine.find("div", class_="description Ice") or engine.find("div", class_="description Electric") or engine.find("div", class_="description Fire") or engine.find("div", class_="description Physical") or engine.find("div", class_="description Ether") or engine.find("div", class_="description")
    base_atk = engine.find("span", class_="value")
    # sub_stat_name = engine.find("span", class_="name").next_sibling
    sub_stat_name = engine.find("span", class_="name")
    # substat_value = 
    print(name.text.strip())
    print(rarity.text.strip())
    print(specialty.text.strip())
    print(description.text.strip())
    print(base_atk.text.strip())
    print(sub_stat_name.text.strip())
    print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/hb/bv28qz_15y52c7ff9q3ls4m40000gn/T/ipykernel_1310/18135692.py in <module>
#       7     base_atk = engine.find("span", class_="value")
#       8     # sub_stat_name = engine.find("span", class_="name").next_sibling
# ----> 9     sub_stat_name = engine.find("span", class_="name") [2]
#      10     # substat_value =
#      11     print(name.text.strip())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bs4/element.py in __getitem__(self, key)
#    1517         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1518         and throws an exception if it's not there."""
# -> 1519         return self.attrs[key]
#    1520
#    1521     def __iter__(self):
#
# KeyError: 2

# %%
for ele in engine.find_all('span', {"class":"name"}): 
   print(name.text)
# Out:
# [Vortex] Revolver
# [Vortex] Revolver

# %%
GraphicPrice = soup.findAll('div', class_='stat')

for price in GraphicPrice:
    prices = price.find('span', class_='name')
    if prices is None:
        pass
    else:
        print(prices.text)
# Out:
# Base ATK (Lv 60):
# Crit Rate (Lv 60):
# Base ATK (Lv 60):
# PEN Ratio (Lv 60):
# Base ATK (Lv 60):
# Impact (Lv 60):
# Base ATK (Lv 60):
# Impact (Lv 60):
# Base ATK (Lv 60):
# Crit Damage (Lv 60):
# Base ATK (Lv 60):
# Anomaly Proficiency (Lv 60):
# Base ATK (Lv 60):
# Crit Rate (Lv 60):
# Base ATK (Lv 60):
# Attack (Lv 60):
# Base ATK (Lv 60):
# Impact (Lv 60):
# Base ATK (Lv 60):
# Impact (Lv 60):
# Base ATK (Lv 60):
# PEN Ratio (Lv 60):
# Base ATK (Lv 60):
# Attack (Lv 60):
# Base ATK (Lv 60):
# Defense (Lv 60):
# Base ATK (Lv 60):
# Defense (Lv 60):
# Base ATK (Lv 60):
# Crit Rate (Lv 60):
# Base ATK (Lv 60):
# Impact (Lv 60):
# Base ATK (Lv 60):
# Energy Regen (Lv 60):
# Base ATK (Lv 60):
# Anomaly Proficiency (Lv 60):
# Base ATK (Lv 60):
# Attack (Lv 60):
# Base ATK (Lv 60):
# Attack (Lv 60):
# Base ATK (Lv 60):
# Energy Regen (Lv 60):
# Base ATK (Lv 60):
# HP (Lv 60):
# Base ATK (Lv 60):
# Attack (Lv 60):
# Base ATK (Lv 60):
# Impact (Lv 60):
# Base ATK (Lv 60):
# ...
